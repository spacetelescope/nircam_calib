# %% [markdown]
# # GSEG data validation

# %% [markdown]
# This notebook contains code that can be used to validate data created during GSEG3. It reads in the APT-derived xml and pointing files and constructs a dictionary of expected data properties. It then compares these properties to the information contained in the headers of the actual data to look for inconsistencies.
#
# **Mirage and pysiaf are dependencies. Be sure they are installed in your environment.**

# %%
from astropy.io import fits
from astropy.table import Table
from collections import OrderedDict
from glob import glob
from mirage.yaml import yaml_generator
from mirage.apt import apt_inputs
from mirage.seed_image.catalog_seed_image import Catalog_seed
from mirage.utils.siaf_interface import sci_subarray_corners
from mirage.utils.utils import calc_frame_time
from mirage.yaml.generate_observationlist import get_observation_dict
import numpy as np
import os
import pkg_resources
import pysiaf

# %% [markdown]
# ## User Inputs

# %%
# The observations to validate (use 3 characters); if you want to validate all
# observations in a proposal, just set observations = []
observations = ['191','192','193','194','195','196','197','198', '199', '200', '201']

# %%
# Header keywords to check against APT-derived dictionary
# It is assumed that these header keywords exist in both the uncal and rate images
KEYWORDS = ['SUBARRAY', 'DETECTOR', 'NINTS', 'NGROUPS', 'NAXIS', 'EFFEXPTM',
            'LONGFILTER', 'LONGPUPIL', 'SHORTFILTER', 'SHORTPUPIL', 'READPATT',
            'OBSLABEL', 'EXP_TYPE', 'TITLE', 'OBSERVTN', 'TEMPLATE',
            'EXPRIPAR', 'SUBSTRT1', 'SUBSTRT2', 'SUBSIZE1', 'SUBSIZE2',
            'FASTAXIS', 'SLOWAXIS', 'PATTTYPE']

# %%
# Corresponding keywords in the APT-derived dictionary
# These must correspond one-to-one with KEYWORDS above
TABLE_KEYWORDS = ['Subarray', None, 'Integrations', 'Groups', None, None,
                  'LongFilter', 'LongPupil', 'ShortFilter', 'ShortPupil', 'ReadoutPattern',
                  'ObservationName', 'Mode', 'Title', 'ObservationID', 'APTTemplate',
                  'ParallelInstrument', None, None, None, None,
                  None, None, 'PrimaryDitherType']

# %%
# Dictionary of header keywords and their expected values in the 
# PRIMARY and SCI extensions of the UNCAL, DARK, and RATE files.
# These are useful when you know exactly what these keywords should be
# for every file (e.g. NAXIS should always be 2 in the RATE image SCI header).
# These will be checked in addition to the KEYWORDS checks above
UNCAL_PRIMARY_KEYWORDS = {}
UNCAL_SCI_KEYWORDS = {'BITPIX':16, 'NAXIS':4, 'BUNIT':'DN'}
DARK_PRIMARY_KEYWORDS = {}
DARK_SCI_KEYWORDS = {'NAXIS':4, 'BUNIT':'DN'}
RATE_PRIMARY_KEYWORDS = {}
RATE_SCI_KEYWORDS = {'BITPIX':-32, 'NAXIS':2, 'BUNIT':'DN/s'}

# %%
# The PRIMARY and SCI header keywords to store for each file in the output summary table
SUMMARY_TABLE_PRIMARY = ['FILENAME', 'DETECTOR', 'FILTER', 'PUPIL', 'EXP_TYPE', 'READPATT', 'NINTS', 'NGROUPS',
                         'NFRAMES', 'GROUPGAP', 'SUBARRAY', 'SUBSTRT1', 'SUBSTRT2', 'SUBSIZE1', 'SUBSIZE2', 
                         'APERNAME']
SUMMARY_TABLE_SCI = ['BITPIX', 'NAXIS', 'NAXIS1', 'NAXIS2', 'NAXIS3', 'NAXIS4', 'BUNIT']

# %% [markdown]
# ## Define some constants

# %%
INTEGER_KEYWORDS = ['Integrations', 'Groups']
FLOAT_KEYWORDS = ['EFFEXPTM']
FILTER_KEYWORDS = ['LONGFILTER', 'LONGPUPIL', 'SHORTFILTER', 'SHORTPUPIL']

# %%
# For FASTAXIS and SLOWAXIS
HORIZONTAL_FLIP = ['NRCA1', 'NRCA3', 'NRCALONG', 'NRCB2', 'NRCB4']
VERTICAL_FLIP = ['NRCA2', 'NRCA4', 'NRCB1', 'NRCB3', 'NRCBLONG']

# %%
# Expected detectors used for each module_subarray combo (these are not always perfect)
DETECTOR_DICT = {'ALL_FULL':['NRCA1', 'NRCA2', 'NRCA3', 'NRCA4', 'NRCALONG',
                             'NRCB1', 'NRCB2', 'NRCB3', 'NRCB4', 'NRCBLONG'],
                 'A_FULL':['NRCA1', 'NRCA2', 'NRCA3', 'NRCA4', 'NRCALONG'],
                 'A_SUBGRISM256':['NRCA1', 'NRCA3','NRCALONG'],
                 'A_SUBGRISM128':['NRCA1', 'NRCA3','NRCALONG'],
                 'A_SUBGRISM64':['NRCA1', 'NRCA3','NRCALONG'],
                 'B_FULL':['NRCB1', 'NRCB2', 'NRCB3', 'NRCB4', 'NRCBLONG'],
                 'B_SUB640':['NRCB1', 'NRCB2', 'NRCB3', 'NRCB4', 'NRCBLONG'],
                 'B_SUB320':['NRCB1', 'NRCB2', 'NRCB3', 'NRCB4', 'NRCBLONG'],
                 'B_SUB160':['NRCB1', 'NRCB2', 'NRCB3', 'NRCB4', 'NRCBLONG'],
                 'B_SUB400P':['NRCB1', 'NRCBLONG'],
                 'B_SUB160P':['NRCB1', 'NRCBLONG'],
                 'B_SUB64P':['NRCB1', 'NRCBLONG']}

# %% [markdown]
# ## Define functions

# %%
def add_entry(filename, summary_dict):
    """Adds an entry for filename to the output summary dict
    """
    for key in SUMMARY_TABLE_PRIMARY:
        try:
            val = str(fits.getheader(filename, 'PRIMARY')[key])
        except KeyError:
            val = ''
        summary_dict[key].append(val)
    
    for key in SUMMARY_TABLE_SCI:
        try:
            val = str(fits.getheader(filename, 'SCI')[key])
        except KeyError:
            val = ''
        summary_dict[key].append(val)
    
    return summary_dict

# %%
def adjust_exptype(value):
    """Modify the exposure type as listed in the exposure table
    to match one of the strings as used in the fits files.
    e.g. 'imaging' becomes 'NRC_IMAGE'
    Remember that currently, Mirage only knows imaging and wfss
    """
    if value == 'imaging':
        return 'NRC_IMAGE'
    elif value == 'wfss':
        return 'NRC_GRISM'

# %%
def calculate_total_files(exp_dict, index):
    """Calculate the total number of files expected for an
    observation based on the number of dithers and the 
    module/subarray combination.
    """
    module = exp_dict['Module'][index].upper()
    subarray = exp_dict['Subarray'][index].upper()
    subarray = subarray.replace('DHSPILA', '').replace('DHSPILB', '')
    number_of_dithers = exp_dict['number_of_dithers'][index]
    combo = '{}_{}'.format(module, subarray)
    
    # Find expected number of detectors based on module/subarray combo
    try:
        expected_detectors = DETECTOR_DICT[combo]
        n_detectors = len(expected_detectors)
    except KeyError:
        print('Warning: module/subbary={} not an expected '
              'combination; assuming all 10 detectors used.'.format(combo))
        n_detectors = 10
        expected_detectors = DETECTOR_DICT['ALL_FULL']
    
    # Find total expected number of files/detectors based on detectors/dithers
    total = number_of_dithers * n_detectors
    expected_detectors = expected_detectors * number_of_dithers
    
    return total, expected_detectors

# %%
def check_apername(sub, aperture):
    """Check that APT subarray is consistent with header APERNAME"""
    n = [s for s in sub if s.isdigit()]
    n = [''.join(n[:])][0]  # number from subarray
    nn = [s for s in aperture.split('_')[1] if s.isdigit()]  # split[1] to get rid of ends of e.g. NRCA5_GRISM256_F277W
    nn = [''.join(nn[:])][0]  # number from header aperture
    if ((n != nn) |
        (('GRISM' in sub) & ('GRISM' not in aperture)) |
        (('GRISM' in aperture) & ('GRISM' not in sub)) |
        ((n+'P' in sub) & (n+'P' not in aperture)) |
        ((n+'P' in aperture) & (n+'P' not in sub)) |
        (('FULL' in sub) & ('FULL' not in aperture)) |
        (('FULL' in aperture) & ('FULL' not in sub))):
        print('WARNING: Mismatch between APT Subarray ({}) and APERNAME ({})'.format(sub, aperture))

# %%
def check_detector_exposures(matching_uncal_files, matching_rate_files, expected_detectors):
    """Ensures both an uncal and rate file exists for each expected detector.
    """
    expected_detectors = np.array(expected_detectors)
    for detector in expected_detectors:
        n_dets = len(expected_detectors[expected_detectors==detector])
        n_files = 0
        for f in matching_uncal_files:
            if detector.lower() in f:
                n_files += 1
        if n_files != n_dets:
            print('WARNING: Expected {} uncal files for detector {}, but found {}'.format(n_dets, detector, n_files))
        n_files = 0
        for f in matching_rate_files:
            if detector.lower() in f:
                n_files += 1
        if n_files != n_dets:
            print('WARNING: Expected {} rate files for detector {}, but found {}'.format(n_dets, detector, n_files))

# %%
def equalize_file_lists(uncal, rate):
    """Given lists of uncal and rate files corresponding to a single
    observation, adjust the lists to be the same length, adding in
    None for any files that are missing in a given list
    """
    udict = {}
    rdict = {}
    expanded_rate = []
    expanded_uncal = []

    # Loop through uncal files and look for matching rate files
    for ufile in uncal:
        dirname, filename = os.path.split(ufile)
        base = filename.strip('_uncal.fits')
        fullbase = os.path.join(dirname, base)
        found = False
        for rfile in rate:
            if fullbase in rfile:
                found = True
                break
        udict[fullbase] = found

    # Loop through rate files and look for matching uncal files
    for rfile in rate:
        dirname, filename = os.path.split(rfile)
        base = filename.strip('_rate.fits')
        fullbase = os.path.join(dirname, base)
        found = False
        for ufile in uncal:
            if fullbase in ufile:
                found = True
                break
        rdict[fullbase] = found

    # Fill in missing files, in either uncal or rate lists,
    # with None
    for ukey in udict:
        expanded_uncal.append(ukey + '_uncal.fits')
        if udict[ukey]:
            expanded_rate.append(ukey + '_rate.fits')
        else:
            expanded_rate.append(None)
    for rkey in rdict:
        if not rdict[rkey]:
            expanded_rate.append(rkey + '_rate.fits')
            expanded_uncal.append(None)
    return expanded_uncal, expanded_rate

# %%
def find_fastaxis(detector):
    """Identify the values of FASTAXIS and SLOWAXIS based on the detector
    name
    """
    if detector in HORIZONTAL_FLIP:
        fast = -1
        slow = 2
    elif detector in VERTICAL_FLIP:
        fast = 1
        slow = -2
    return fast, slow

# %%
def find_rate_files(gseg_uncal_files):
    """Returns a list of rate files that correspond to the 
    input uncal files. These may be either rate.fits files 
    or dark.fits files."""
    
    gseg_rate_files = []
    for f in gseg_uncal_files:
        rate_file = f.replace('uncal.fits','rate.fits')
        dark_file = f.replace('uncal.fits','dark.fits')
        if os.path.isfile(rate_file):
            gseg_rate_files.append(rate_file)
        elif os.path.isfile(dark_file):
            gseg_rate_files.append(dark_file)
        else:
            print('Warning: No corresponding rate file for {}'.format(f))
    
    return gseg_rate_files

# %%
def get_data(filename):
    """Read in the given fits file and return the data and header
    """
    with fits.open(filename) as h:
        signals = h['SCI'].data
        header0 = h[0].header
        header1 = h[1].header
    return signals, header0, header1

# %%
def get_expected_shape(sub):
    """Returns the expected shape of the science data
    based on the input APT subarray.
    """
    siaf = pysiaf.Siaf('NIRCam')
    subarray = sub.replace('SUB', '').replace('DHSPILA', '').replace('DHSPILB', '')
    
    if 'FULL' in subarray:
        expected_shape = (2048, 2048)
    else:
        # needed to be careful here to remove cases where e.g. SUB64 was in SUB640
        similar_aps = [aper for aper in siaf.apernames if subarray in aper and subarray+'0' not in aper]
        if len(similar_aps) == 0:
            print('WARNING: Cannot find expected shape for subarray {}'.format(sub))
            expected_shape = (-99, -99)
        else:
            # just use first entry to get expected shape since they should all be the same
            similar_ap = similar_aps[0]
            expected_shape = (siaf[similar_ap].YSciSize, siaf[similar_ap].XSciSize)
    
    return expected_shape

# %%
def header_keywords(head):
    """Extract values for the desired keywords from the given header
    """
    file_info = {}
    for keyword in KEYWORDS:
        try:
            info = head[keyword]
        except KeyError:
            if 'FILTER' in keyword:
                info = head['FILTER']
            elif 'PUPIL' in keyword:
                info = head['PUPIL']
            else:
                info = None

        file_info[keyword] = info
    return file_info

# %%
def table_info(values, index):
    """Extract information from the exposure table that matches the
    header keyword values in KEYWORDS
    """
    values_dict = {}
    for table_keyword, file_keyword in zip(TABLE_KEYWORDS, KEYWORDS):
        if table_keyword is not None:
            if table_keyword in INTEGER_KEYWORDS:
                value = int(values[table_keyword][index])
            else:
                value = values[table_keyword][index]
            values_dict[file_keyword] = value
        else:
            values_dict[file_keyword] = None
    return values_dict

# %%
def verify_dimensions(filename, file_type, expected_shape):
    """Verify the header and data dimensions for each extension.
    """
    header = fits.getheader(filename, 'PRIMARY')
    if file_type == 'UNCAL':
        extensions = ['SCI']
        primary_header_shape = (header['NINTS'], header['NGROUPS'], header['SUBSIZE2'], header['SUBSIZE1'])
        for ext in extensions:
            try:
                header = fits.getheader(filename, ext)
                data_shape = fits.getdata(filename, ext).shape
                naxis_shape = (header['NAXIS4'], header['NAXIS3'], header['NAXIS2'], header['NAXIS1'])
                if ((primary_header_shape != data_shape) | (primary_header_shape != naxis_shape) | 
                    (primary_header_shape[-2:] != expected_shape)):
                    print('WARNING: Data dimensions incorrect')
                    print('Expected image shape: {}'.format(expected_shape))
                    print('PRIMARY header shape: {}'.format(primary_header_shape))
                    print('{} header shape: {}'.format(ext, naxis_shape))
                    print('{} data shape: {}'.format(ext, data_shape)) 
            except KeyError:
                print('Cannot verify shape for {} extension'.format(ext))
    elif file_type == 'DARK':
        extensions = 'SCI PIXELDQ GROUPDQ ERR'.split()
        primary_header_shape = (header['NINTS'], header['NGROUPS'], header['SUBSIZE2'], header['SUBSIZE1'])
        for ext in extensions:
            try:
                header = fits.getheader(filename, ext)
                data_shape = fits.getdata(filename, ext).shape
                # PIXELDQ extension is only 2D and doesnt have NAXIS3/4, 
                # so just make it 4D by appending expected results
                if ext == 'PIXELDQ':
                    data_shape = (primary_header_shape[0], primary_header_shape[1], data_shape[0], data_shape[1])
                    naxis_shape = (primary_header_shape[0], primary_header_shape[1], header['NAXIS2'], header['NAXIS1'])
                else:
                    naxis_shape = (header['NAXIS4'], header['NAXIS3'], header['NAXIS2'], header['NAXIS1'])
                if ((primary_header_shape != data_shape) | (primary_header_shape != naxis_shape) | 
                    (primary_header_shape[-2:] != expected_shape)):
                    print('WARNING: Data dimensions incorrect')
                    print('Expected image shape: {}'.format(expected_shape))
                    print('PRIMARY header shape: {}'.format(primary_header_shape))
                    print('{} header shape: {}'.format(ext, naxis_shape))
                    print('{} data shape: {}'.format(ext, data_shape))
            except KeyError:
                print('Cannot verify shape for {} extension'.format(ext))
    elif file_type == 'RATE':
        extensions = 'SCI ERR DQ VAR_POISSON VAR_RNOISE'.split()
        primary_header_shape = (header['SUBSIZE2'], header['SUBSIZE1'])
        for ext in extensions:
            try:
                header = fits.getheader(filename, ext)
                data_shape = fits.getdata(filename, ext).shape
                naxis_shape = (header['NAXIS2'], header['NAXIS1'])
                if ((primary_header_shape != data_shape) | (primary_header_shape != naxis_shape) | 
                    (primary_header_shape != expected_shape)):
                    print('WARNING: Data dimensions incorrect')
                    print('Expected image shape: {}'.format(expected_shape))
                    print('PRIMARY header shape: {}'.format(primary_header_shape))
                    print('{} header shape: {}'.format(ext, naxis_shape))
                    print('{} data shape: {}'.format(ext, data_shape))
            except KeyError:
                print('Cannot verify shape for {} extension'.format(ext))
    else:
        print('File type {} not supported for dimension checks'.format(file_type))

# %%
def verify_extensions(filename, file_type):
    """Verify that the expected extensions exist
    """
    if file_type == 'UNCAL':
        extensions = 'PRIMARY SCI GROUP INT_TIMES ASDF'.split()
    elif file_type == 'DARK':
        extensions = 'PRIMARY SCI PIXELDQ GROUPDQ ERR GROUP INT_TIMES ASDF'.split()
    elif file_type == 'RATE':
        extensions = 'PRIMARY SCI ERR DQ VAR_POISSON VAR_RNOISE ASDF'.split()
    else:
        print('File type {} not supported for ext verification'.format(file_type))
        
    for ext in extensions:
        try:
            header = fits.getheader(filename, ext)
        except KeyError:
            print('WARNING: {} extension does not exist'.format(ext))

# %% [markdown]
# ## The main function

# %%
def validate(xml_file, output_dir, gseg_uncal_files):
    """MAIN FUNCTION"""
    
    read_pattern_def_file = os.path.join(pkg_resources.resource_filename('mirage', ''), 
                                         'config', 'nircam_read_pattern_definitions.list')
    
    # Make an empty dictionary to store output summary table info
    summary_dict = OrderedDict()
    cols = SUMMARY_TABLE_PRIMARY + SUMMARY_TABLE_SCI
    for col in cols:
        summary_dict[col] = []
    
    # Find the corresponding rate files for each uncal file
    gseg_rate_files = find_rate_files(gseg_uncal_files)
    
    # Create apt-derived dictionary
    pointing_file = xml_file.replace('.xml', '.pointing')
    catalogs = {'nircam': {'sw': 'nothing.cat', 'lw': 'nothing.cat'}}
    observation_list_file = os.path.join(output_dir, 'observation_list.yaml')
    apt_xml_dict = get_observation_dict(xml_file, observation_list_file, catalogs,
                                        verbose=True)
    
    # Find observations to validate, either all in proposal or user-specified
    observation_list = set(apt_xml_dict['ObservationID'])
    if len(observations) != 0:
        str_obs_list = observations
    else:
        int_obs = sorted([int(o) for o in observation_list])
        str_obs_list = [str(o).zfill(3) for o in int_obs]
    
    for observation_to_check in str_obs_list:
        print('')
        print('')
        print('OBSERVATION: {}'.format(observation_to_check))
        print('')
        
        good = np.where(np.array(apt_xml_dict['ObservationID']) == observation_to_check)
        module = apt_xml_dict['Module'][good[0][0]].upper()
        
        try:
            total_expected_files, expected_detectors = calculate_total_files(apt_xml_dict, good[0][0])
            print('Total number of expected files: {}'.format(total_expected_files))
            print('Expected detectors used: {}'.format(expected_detectors))
        except IndexError:
            print("No files found.")
            continue

        # The complication here is that the table created by Mirage does not have a filename
        # attached to each entry. So we need a way to connect an actual filename
        # to each entry
        subdir_start = 'jw' + apt_xml_dict['ProposalID'][good[0][0]] + observation_to_check.zfill(3)
        matching_uncal_files = sorted([filename for filename in gseg_uncal_files if subdir_start in filename])
        matching_rate_files = sorted([filename for filename in gseg_rate_files if subdir_start in filename])
        print('Found uncal files:')
        for i in range(len(matching_uncal_files)):
            print(matching_uncal_files[i])
        print('')
        print('Found rate files:')
        for i in range(len(matching_rate_files)):
            print(matching_rate_files[i])
        print('')
        
        # Check for any missing files and that a file exists for each expected detector used
        check_detector_exposures(matching_uncal_files, matching_rate_files, expected_detectors)
        
        # Deal with the case of matching_uncal_files and matching_rate_files having
        # different lengths here. In order to loop over them they must have the same length
        if len(matching_uncal_files) != len(matching_rate_files):
            (matching_uncal_files, matching_rate_files) = equalize_file_lists(matching_uncal_files, matching_rate_files)
            print('Equalized file lists (should have a 1:1 correspondence):')
            for idx in range(len(matching_uncal_files)):
                print(matching_uncal_files[idx], matching_rate_files[idx])

        # Create siaf instance for later calculations
        siaf = pysiaf.Siaf('NIRCam')

        for file_pair in zip(matching_uncal_files, matching_rate_files):
            for f in file_pair: 
                # Only validate files that exist
                good_file = f != None
                if good_file:
                    if not os.path.isfile(f):
                        print('WARNING: File does not exist: {}'.format(f))
                        good_file = False
                
                if good_file:
                    print("Checking {}".format(os.path.split(f)[1]))
                    print('----------------------------------------------------')
                    file_type = f.split('.fits')[0].split('_')[-1].upper()
                else:
                    continue
                
                # Verify that all expected extensions exist for this file and add
                # file info to the output summary table
                verify_extensions(f, file_type)
                summary_dict = add_entry(f, summary_dict)
                
                # Get info from header to be compared
                data, header, sci_header = get_data(f)
                header_vals = header_keywords(header)

                # Get matching data from the APT exposure table
                table_vals = table_info(apt_xml_dict, good[0][0])
                
                # Verify that the header and data dimensions are correct in each extension
                expected_shape = get_expected_shape(table_vals['SUBARRAY'])
                verify_dimensions(f, file_type, expected_shape)
                
                # Check detector/aperture
                detector_from_filename = f.split('_')[-2].upper()
                header_detector = header['DETECTOR']
                aperture = header['APERNAME']  # could also try APERNAME, PPS_APER
                if 'LONG' in header_detector:
                    header_detector = header_detector.replace('LONG', '5')
                if header_detector not in aperture:
                    print(("WARNING: Detector name and aperture name in file header appear to be incompatible: {}, {}"
                          .format(header['DETECTOR'], aperture)))
                    print("Detector listed in filename: {}".format(detector_from_filename))
                    print('If the aperture is incorrect then the calculated subarray '
                          'location from pysiaf will also be incorrect.')
                check_apername(table_vals['SUBARRAY'], aperture)  # make sure APT subarray is consistent with header APERNAME
                data_shape = data.shape
                
                # Compare NFRAME, GROUPGAP from header with expected values based on READPATT
                m = Catalog_seed()
                params = {'Readout': {'readpatt': table_vals['READPATT']},
                          'Reffiles': {'readpattdefs': read_pattern_def_file}}
                m.params = params
                m.read_pattern_check()
                nframes = m.params['Readout']['nframe']
                groupgap = m.params['Readout']['nskip']
                if nframes != header['NFRAMES']:
                    print('WARNING: NFRAME mismatch between header ({}) and expected value ({}).'.format(
                          nframes, header['NFRAMES']))
                if groupgap != header['GROUPGAP']:
                    print('WARNING: GROUPGAP mismatch between header ({}) and expected value ({}).'.format(
                          groupgap, header['GROUPGAP']))

                # Make some adjustments to the exposure table info

                # Calucate the exposure time
                if 'FULL' in table_vals['SUBARRAY']:
                    num_amps = 4
                else:  # assume all grism and sub use 1 amp outputs
                    num_amps = 1
                frametime = calc_frame_time('NIRCam', aperture, data_shape[-1], data_shape[-2], num_amps)
                table_vals['EFFEXPTM'] = frametime * (table_vals['NGROUPS'] * (nframes+groupgap) - groupgap)

                # NAXIS
                table_vals['NAXIS'] = len(data.shape)
                header_vals['NAXIS'] = sci_header['NAXIS']

                # Use pysiaf to calculate subarray locations
                try:
                    xc, yc = sci_subarray_corners('NIRCam', aperture, siaf=siaf)
                    table_vals['SUBSTRT1'] = xc[0] + 1
                    table_vals['SUBSTRT2'] = yc[0] + 1
                    table_vals['SUBSIZE1'] = siaf[aperture].XSciSize
                    table_vals['SUBSIZE2'] = siaf[aperture].YSciSize
                except KeyError:
                    print("ERROR: Aperture {} is not a valid aperture in pysiaf.".format(aperture))
                    xc = [-2, -2]
                    yc = [-2, -2]
                    table_vals['SUBSTRT1'] = xc[0] + 1
                    table_vals['SUBSTRT2'] = yc[0] + 1
                    table_vals['SUBSIZE1'] = 9999
                    table_vals['SUBSIZE2'] = 9999

                # Create FASTAXIS and SLOWAXIS values based on the detector name
                fast, slow = find_fastaxis(header_vals['DETECTOR'])
                table_vals['FASTAXIS'] = fast
                table_vals['SLOWAXIS'] = slow

                # Remove whitespace from observing template in file
                header_vals['TEMPLATE'] = header_vals['TEMPLATE'].replace(' ', '').lower()
                table_vals['TEMPLATE'] = table_vals['TEMPLATE'].lower()

                # Adjust prime/parallel boolean from table to be a string
                if not table_vals['EXPRIPAR']:
                    table_vals['EXPRIPAR'] = 'PRIME'
                else:
                    table_vals['EXPRIPAR'] = 'PARALLEL'

                # Change exposure type from table to match up with
                # types of strings in the file
                table_vals['EXP_TYPE'] = adjust_exptype(table_vals['EXP_TYPE'])

                # Set the DETECTOR field to be identical. This info is not in the
                # exposure table, so we can't actually check it
                table_vals['DETECTOR'] = header_vals['DETECTOR']

                # Now compare the data in the dictionary from the file versus that
                # from the exposure table created from the APT file
                err = False
                for key in header_vals:
                    if header_vals[key] != table_vals[key]:
                        if key not in FLOAT_KEYWORDS and key not in FILTER_KEYWORDS:
                            err = True
                            print('MISMATCH: {}, in exp table: {}, in file: {}'.format(key, table_vals[key], header_vals[key]))
                        elif key in FLOAT_KEYWORDS:
                            if not np.isclose(header_vals[key], table_vals[key], rtol=0.01, atol=0.):
                                err = True
                                print('MISMATCH: {}, in exp table: {}, in file: {}'.format(key, table_vals[key], header_vals[key]))

                        if key in ['LONGFILTER', 'LONGPUPIL'] and 'LONG' in header_vals['DETECTOR']:
                            err = True
                            print('MISMATCH: {}, in exp table: {}, in file: {}'.format(key, table_vals[key], header_vals[key]))
                        if key in ['SHORTFILTER', 'SHORTPUPIL'] and 'LONG' not in header_vals['DETECTOR']:
                            err = True
                            print('MISMATCH: {}, in exp table: {}, in file: {}'.format(key, table_vals[key], header_vals[key]))
                
                # Perform direct comparison between header keywords and their expected values
                if file_type == 'UNCAL':
                    for key in UNCAL_PRIMARY_KEYWORDS:
                        if UNCAL_PRIMARY_KEYWORDS[key] != header[key]:
                            err = True
                            print('MISMATCH: {}, expected: {}, in file: {}'.format(
                                  key, UNCAL_PRIMARY_KEYWORDS[key], header[key]))
                    for key in UNCAL_SCI_KEYWORDS:
                        if UNCAL_SCI_KEYWORDS[key] != sci_header[key]:
                            err = True
                            print('MISMATCH: {}, expected: {}, in file: {}'.format(
                                  key, UNCAL_SCI_KEYWORDS[key], sci_header[key]))
                elif file_type == 'DARK':
                    for key in DARK_PRIMARY_KEYWORDS:
                        if DARK_PRIMARY_KEYWORDS[key] != header[key]:
                            err = True
                            print('MISMATCH: {}, expected: {}, in file: {}'.format(
                                  key, DARK_PRIMARY_KEYWORDS[key], header[key]))
                    for key in DARK_SCI_KEYWORDS:
                        if DARK_SCI_KEYWORDS[key] != sci_header[key]:
                            err = True
                            print('MISMATCH: {}, expected: {}, in file: {}'.format(
                                  key, DARK_SCI_KEYWORDS[key], sci_header[key]))
                elif file_type == 'RATE':
                    for key in RATE_PRIMARY_KEYWORDS:
                        if RATE_PRIMARY_KEYWORDS[key] != header[key]:
                            err = True
                            print('MISMATCH: {}, expected: {}, in file: {}'.format(
                                  key, RATE_PRIMARY_KEYWORDS[key], header[key]))
                    for key in RATE_SCI_KEYWORDS:
                        if RATE_SCI_KEYWORDS[key] != sci_header[key]:
                            err = True
                            print('MISMATCH: {}, expected: {}, in file: {}'.format(
                                  key, RATE_SCI_KEYWORDS[key], sci_header[key]))
                else:
                    print('No direct header checks performed for {} file type.'.format(file_type))

                if not err:
                    print('No inconsistencies. File header info correct.')
                    
                print('')

            print('')
            print('')
    
    # Output the summary table
    summary_table = Table(summary_dict)
    summary_table.write(os.path.join(output_dir, 'summary_table.txt'), format='ascii.fixed_width_two_line')

# %% [markdown]
# ## Run the tool

# %%
xml_file = '/path/to/proposal/xml/file/00617.xml'
output_dir = '/location/to/place/outputs/'
gseg_uncal_files = glob('/path/to/gseg/files/*uncal.fits')

# %%
validate(xml_file, output_dir, gseg_uncal_files)

# %%
xml_file = '/Volumes/LaCie/gseg_validation_tests/APT_00617_full/617.xml'
output_dir = '/Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/outputs/'
gseg_uncal_files = glob('/Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/*/*uncal.fits')
validate(xml_file, output_dir, gseg_uncal_files)
# Out:
# target_info:
# {'ALF-CMA-R': ('06:35:19.5590', '-66:49:7.12')}
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `001` labelled `NIRCam EO-1 GSEG3E1-OTB-20190122 ModB-SUB640` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 0 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 001 NIRCam EO-1 GSEG3E1-OTB-20190122 ModB-SUB640
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 1 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `002` labelled `NIRCam EO-2 GSEG3E1-OTB-20190122 ModB-SUB320` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 1 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 002 NIRCam EO-2 GSEG3E1-OTB-20190122 ModB-SUB320
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 2 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `003` labelled `NIRCam EO-3 GSEG3-OTB-20190122 ModB-SUB160` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 2 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 003 NIRCam EO-3 GSEG3-OTB-20190122 ModB-SUB160
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 3 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `004` labelled `NIRCam EO-4 GSEG3-OTB-20190122 ModB-SUB400P` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 3 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 004 NIRCam EO-4 GSEG3-OTB-20190122 ModB-SUB400P
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 4 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `005` labelled `NIRCam EO-5 GSEG3-OTB-20190122 ModB-SUB160P` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 4 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 005 NIRCam EO-5 GSEG3-OTB-20190122 ModB-SUB160P
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 5 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `006` labelled `NIRCam EO-6 GSEG3-OTB-20190122 ModB-SUB64P` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 5 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 006 NIRCam EO-6 GSEG3-OTB-20190122 ModB-SUB64P
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 6 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `007` labelled `NIRCam EO-7 GSEG3-OTB-20190122 ModB-SUBGRISM256` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 6 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 007 NIRCam EO-7 GSEG3-OTB-20190122 ModB-SUBGRISM256
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 7 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `008` labelled `NIRCam EO-8 GSEG3-OTB-20190122 ModB-SUBGRISM128` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 7 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 008 NIRCam EO-8 GSEG3-OTB-20190122 ModB-SUBGRISM128
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 8 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `009` labelled `NIRCam EO-9 GSEG3-OTB-20190122 ModB-SUBGRISM64` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 8 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 009 NIRCam EO-9 GSEG3-OTB-20190122 ModB-SUBGRISM64
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 9 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `010` labelled `NIRCam EO-10 GSEG3-OTB-20190122 ModB-SUB96DHSPILB` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 9 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 010 NIRCam EO-10 GSEG3-OTB-20190122 ModB-SUB96DHSPILB
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 10 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `011` labelled `NIRCam EO-11 GSEG3-OTB-20190122 ModA-SUB640` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 10 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 011 NIRCam EO-11 GSEG3-OTB-20190122 ModA-SUB640
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 11 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `012` labelled `NIRCam EO-12 GSEG3-OTB-20190122 ModA-SUB320` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 11 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 012 NIRCam EO-12 GSEG3-OTB-20190122 ModA-SUB320
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 12 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `013` labelled `NIRCam EO-13 GSEG3-OTB-20190122 ModA-SUB160` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 12 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 013 NIRCam EO-13 GSEG3-OTB-20190122 ModA-SUB160
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 13 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `014` labelled `NIRCam EO-14 GSEG3-OTB-20190122 ModA-SUB400P` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 13 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 014 NIRCam EO-14 GSEG3-OTB-20190122 ModA-SUB400P
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 14 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `015` labelled `NIRCam EO-15 GSEG3-OTB-20190122 ModA-SUB160P` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 14 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 015 NIRCam EO-15 GSEG3-OTB-20190122 ModA-SUB160P
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 15 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `016` labelled `NIRCam EO-16 GSEG3-OTB-20190122 ModA-SUB64P` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 15 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 016 NIRCam EO-16 GSEG3-OTB-20190122 ModA-SUB64P
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 16 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `017` labelled `NIRCam EO-17 GSEG3-OTB-20190122 ModA-SUBGRISM256` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 16 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 017 NIRCam EO-17 GSEG3-OTB-20190122 ModA-SUBGRISM256
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 17 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `018` labelled `NIRCam EO-18 GSEG3-OTB-20190122 ModA-SUBGRISM128` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 17 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 018 NIRCam EO-18 GSEG3-OTB-20190122 ModA-SUBGRISM128
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 18 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `019` labelled `NIRCam EO-19 GSEG3-OTB-20190122 ModA-SUBGRISM64` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 18 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 019 NIRCam EO-19 GSEG3-OTB-20190122 ModA-SUBGRISM64
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 19 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `020` labelled `NIRCam EO-20 GSEG3-OTB-20190122 ModA-SUBDHSPILA` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 19 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 020 NIRCam EO-20 GSEG3-OTB-20190122 ModA-SUBDHSPILA
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 20 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `021` labelled `NIRCam EO-1 GSEG3E1-OTB-20190122 ModB-SUB640 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 20 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 021 NIRCam EO-1 GSEG3E1-OTB-20190122 ModB-SUB640 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 21 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `022` labelled `NIRCam EO-2 GSEG3E1-OTB-20190122 ModB-SUB320 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 21 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 022 NIRCam EO-2 GSEG3E1-OTB-20190122 ModB-SUB320 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 22 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `023` labelled `NIRCam EO-3 GSEG3-OTB-20190122 ModB-SUB160 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 22 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 023 NIRCam EO-3 GSEG3-OTB-20190122 ModB-SUB160 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 23 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `024` labelled `NIRCam EO-4 GSEG3-OTB-20190122 ModB-SUB400P copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 23 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 024 NIRCam EO-4 GSEG3-OTB-20190122 ModB-SUB400P copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 24 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `025` labelled `NIRCam EO-5 GSEG3-OTB-20190122 ModB-SUB160P copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 24 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 025 NIRCam EO-5 GSEG3-OTB-20190122 ModB-SUB160P copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 25 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `026` labelled `NIRCam EO-6 GSEG3-OTB-20190122 ModB-SUB64P copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 25 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 026 NIRCam EO-6 GSEG3-OTB-20190122 ModB-SUB64P copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 26 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `027` labelled `NIRCam EO-7 GSEG3-OTB-20190122 ModB-SUBGRISM256 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 26 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 027 NIRCam EO-7 GSEG3-OTB-20190122 ModB-SUBGRISM256 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 27 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `028` labelled `NIRCam EO-8 GSEG3-OTB-20190122 ModB-SUBGRISM128 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 27 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 028 NIRCam EO-8 GSEG3-OTB-20190122 ModB-SUBGRISM128 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 28 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `029` labelled `NIRCam EO-9 GSEG3-OTB-20190122 ModB-SUBGRISM64 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 28 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 029 NIRCam EO-9 GSEG3-OTB-20190122 ModB-SUBGRISM64 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 29 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `030` labelled `NIRCam EO-10 GSEG3-OTB-20190122 ModB-SUB96DHSPILB copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 29 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 030 NIRCam EO-10 GSEG3-OTB-20190122 ModB-SUB96DHSPILB copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 30 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `031` labelled `NIRCam EO-11 GSEG3-OTB-20190122 ModA-SUB640 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 30 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 031 NIRCam EO-11 GSEG3-OTB-20190122 ModA-SUB640 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 31 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `032` labelled `NIRCam EO-12 GSEG3-OTB-20190122 ModA-SUB320 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 31 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 032 NIRCam EO-12 GSEG3-OTB-20190122 ModA-SUB320 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 32 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `033` labelled `NIRCam EO-13 GSEG3-OTB-20190122 ModA-SUB160 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 32 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 033 NIRCam EO-13 GSEG3-OTB-20190122 ModA-SUB160 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 33 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `034` labelled `NIRCam EO-14 GSEG3-OTB-20190122 ModA-SUB400P copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 33 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 034 NIRCam EO-14 GSEG3-OTB-20190122 ModA-SUB400P copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 34 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `035` labelled `NIRCam EO-15 GSEG3-OTB-20190122 ModA-SUB160P copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 34 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 035 NIRCam EO-15 GSEG3-OTB-20190122 ModA-SUB160P copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 35 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `036` labelled `NIRCam EO-16 GSEG3-OTB-20190122 ModA-SUB64P copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 35 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 036 NIRCam EO-16 GSEG3-OTB-20190122 ModA-SUB64P copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 36 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `037` labelled `NIRCam EO-17 GSEG3-OTB-20190122 ModA-SUBGRISM256 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 36 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 037 NIRCam EO-17 GSEG3-OTB-20190122 ModA-SUBGRISM256 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 37 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `038` labelled `NIRCam EO-18 GSEG3-OTB-20190122 ModA-SUBGRISM128 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 37 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 038 NIRCam EO-18 GSEG3-OTB-20190122 ModA-SUBGRISM128 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 38 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `039` labelled `NIRCam EO-19 GSEG3-OTB-20190122 ModA-SUBGRISM64 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 38 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 039 NIRCam EO-19 GSEG3-OTB-20190122 ModA-SUBGRISM64 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 39 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `040` labelled `NIRCam EO-20 GSEG3-OTB-20190122 ModA-SUBDHSPILA copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 39 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 040 NIRCam EO-20 GSEG3-OTB-20190122 ModA-SUBDHSPILA copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 40 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `041` labelled `NIRCam EO-1 GSEG3E2-OTB-20190318ModB-SUB640` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 40 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 041 NIRCam EO-1 GSEG3E2-OTB-20190318ModB-SUB640
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 41 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `042` labelled `NIRCam EO-2 GSEG3E2-OTB-20190318 ModB-SUB320` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 41 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 042 NIRCam EO-2 GSEG3E2-OTB-20190318 ModB-SUB320
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 42 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `043` labelled `NIRCam EO-3 GSEG3E2-OTB-20190318 ModB-SUB160` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 42 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 043 NIRCam EO-3 GSEG3E2-OTB-20190318 ModB-SUB160
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 43 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `044` labelled `NIRCam EO-4 GSEG3E2-OTB-20190318 ModB-SUB400P` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 43 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 044 NIRCam EO-4 GSEG3E2-OTB-20190318 ModB-SUB400P
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 44 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `045` labelled `NIRCam EO-5 GSEG3E2-OTB-20190318 ModB-SUB160P` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 44 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 045 NIRCam EO-5 GSEG3E2-OTB-20190318 ModB-SUB160P
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 45 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `046` labelled `NIRCam EO-6 GSEG3E2-OTB-20190318 ModB-SUB64P` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 45 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 046 NIRCam EO-6 GSEG3E2-OTB-20190318 ModB-SUB64P
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 46 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `047` labelled `NIRCam EO-7 GSEG3E2-OTB-20190318 ModB-SUBGRISM256` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 46 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 047 NIRCam EO-7 GSEG3E2-OTB-20190318 ModB-SUBGRISM256
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 47 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `048` labelled `NIRCam EO-8 GSEG3E2-OTB-20190318 ModB-SUBGRISM128` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 47 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 048 NIRCam EO-8 GSEG3E2-OTB-20190318 ModB-SUBGRISM128
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 48 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `049` labelled `NIRCam EO-9 GSEG3E2-OTB-20190318 ModB-SUBGRISM64` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 48 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 049 NIRCam EO-9 GSEG3E2-OTB-20190318 ModB-SUBGRISM64
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 49 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `050` labelled `NIRCam EO-10 GSEG3E2-OTB-20190318 ModB-SUB96DHSPILB` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 49 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 050 NIRCam EO-10 GSEG3E2-OTB-20190318 ModB-SUB96DHSPILB
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 50 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `051` labelled `NIRCam EO-11 GSEG3E2-OTB-20190318 ModA-SUB640` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 50 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 051 NIRCam EO-11 GSEG3E2-OTB-20190318 ModA-SUB640
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 51 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `052` labelled `NIRCam EO-12 GSEG3E2-OTB-20190318 ModA-SUB320` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 51 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 052 NIRCam EO-12 GSEG3E2-OTB-20190318 ModA-SUB320
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 52 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `053` labelled `NIRCam EO-13 GSEG3E2-OTB-20190318 ModA-SUB160` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 52 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 053 NIRCam EO-13 GSEG3E2-OTB-20190318 ModA-SUB160
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 53 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `054` labelled `NIRCam EO-14 GSEG3E2-OTB-20190318 ModA-SUB400P` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 53 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 054 NIRCam EO-14 GSEG3E2-OTB-20190318 ModA-SUB400P
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 54 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `055` labelled `NIRCam EO-15 GSEG3E2-OTB-20190318 ModA-SUB160P` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 54 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 055 NIRCam EO-15 GSEG3E2-OTB-20190318 ModA-SUB160P
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 55 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `056` labelled `NIRCam EO-16 GSEG3E2-OTB-20190318 ModA-SUB64P` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 55 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 056 NIRCam EO-16 GSEG3E2-OTB-20190318 ModA-SUB64P
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 56 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `057` labelled `NIRCam EO-17 GSEG3E2-OTB-20190318 ModA-SUBGRISM256` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 56 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 057 NIRCam EO-17 GSEG3E2-OTB-20190318 ModA-SUBGRISM256
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 57 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `058` labelled `NIRCam EO-18 GSEG3E2-OTB-20190318 ModA-SUBGRISM128` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 57 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 058 NIRCam EO-18 GSEG3E2-OTB-20190318 ModA-SUBGRISM128
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 58 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `059` labelled `NIRCam EO-19 GSEG3E2-OTB-20190318 ModA-SUBGRISM64` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 58 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 059 NIRCam EO-19 GSEG3E2-OTB-20190318 ModA-SUBGRISM64
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 59 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `060` labelled `NIRCam EO-20 GSEG3E2-OTB-20190318 ModA-SUBDHSPILA` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 59 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 060 NIRCam EO-20 GSEG3E2-OTB-20190318 ModA-SUBDHSPILA
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 60 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `061` labelled `NIRCam EO-1 GSEG3E2-OTB-20190318 ModB-SUB640 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 60 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 061 NIRCam EO-1 GSEG3E2-OTB-20190318 ModB-SUB640 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 61 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `062` labelled `NIRCam EO-2 GSEG3E2-OTB-20190318 ModB-SUB320 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 61 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 062 NIRCam EO-2 GSEG3E2-OTB-20190318 ModB-SUB320 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 62 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `063` labelled `NIRCam EO-3 GGSEG3E2-OTB-20190318 ModB-SUB160 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 62 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 063 NIRCam EO-3 GGSEG3E2-OTB-20190318 ModB-SUB160 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 63 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `064` labelled `NIRCam EO-4 GSEG3E2-OTB-20190318 ModB-SUB400P copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 63 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 064 NIRCam EO-4 GSEG3E2-OTB-20190318 ModB-SUB400P copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 64 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `065` labelled `NIRCam EO-5 GSEG3E2-OTB-20190318 ModB-SUB160P copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 64 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 065 NIRCam EO-5 GSEG3E2-OTB-20190318 ModB-SUB160P copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 65 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `066` labelled `NIRCam EO-6 GSEG3E2-OTB-20190318 ModB-SUB64P copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 65 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 066 NIRCam EO-6 GSEG3E2-OTB-20190318 ModB-SUB64P copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 66 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `067` labelled `NIRCam EO-7 GSEG3E2-OTB-20190318 ModB-SUBGRISM256 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 66 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 067 NIRCam EO-7 GSEG3E2-OTB-20190318 ModB-SUBGRISM256 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 67 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `068` labelled `NIRCam EO-8 GSEG3E2-OTB-20190318 ModB-SUBGRISM128 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 67 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 068 NIRCam EO-8 GSEG3E2-OTB-20190318 ModB-SUBGRISM128 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 68 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `069` labelled `NIRCam EO-9 GSEG3E2-OTB-20190318 ModB-SUBGRISM64 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 68 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 069 NIRCam EO-9 GSEG3E2-OTB-20190318 ModB-SUBGRISM64 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 69 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `070` labelled `NIRCam EO-10 GSEG3E2-OTB-20190318 ModB-SUB96DHSPILB copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 69 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 070 NIRCam EO-10 GSEG3E2-OTB-20190318 ModB-SUB96DHSPILB copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 70 entries after reading template (+1 entries)
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Observation `071` labelled `NIRCam EO-11 GSEG3E2-OTB-20190318 ModA-SUB640 copy` uses template `NircamEngineeringImaging`
# APTObservationParams Dictionary holds 70 entries before reading template
# Primary dither element PrimaryDithers not found, use default primary dithers value (1).
# Number of dithers: 1 primary * 1 subpixel = 1
# Dictionary read from template has 1 entries.
# Found 1 tile(s) for observation 071 NIRCam EO-11 GSEG3E2-OTB-20190318 ModA-SUB640 copy
# Found 1 visits with numbers: [1]
# APTObservationParams Dictionary holds 71 entries after reading template (+1 entries)
# ...
# MISMATCH: EXP_TYPE, in exp table: NRC_IMAGE, in file: NRC_DARK
#
#
#
#
#
# OBSERVATION: 200
#
# Total number of expected files: 10
# Expected detectors used: ['NRCA1', 'NRCA2', 'NRCA3', 'NRCA4', 'NRCALONG', 'NRCB1', 'NRCB2', 'NRCB3', 'NRCB4', 'NRCBLONG']
# Found uncal files:
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrca1/jw00617200001_02101_00001_nrca1_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrca2/jw00617200001_02101_00001_nrca2_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrca3/jw00617200001_02101_00001_nrca3_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrca4/jw00617200001_02101_00001_nrca4_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrcalong/jw00617200001_02101_00001_nrcalong_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrcb1/jw00617200001_02101_00001_nrcb1_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrcb2/jw00617200001_02101_00001_nrcb2_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrcb3/jw00617200001_02101_00001_nrcb3_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrcb4/jw00617200001_02101_00001_nrcb4_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrcblong/jw00617200001_02101_00001_nrcblong_uncal.fits
#
# Found rate files:
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrca1/jw00617200001_02101_00001_nrca1_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrca2/jw00617200001_02101_00001_nrca2_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrca3/jw00617200001_02101_00001_nrca3_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrca4/jw00617200001_02101_00001_nrca4_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrcalong/jw00617200001_02101_00001_nrcalong_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrcb1/jw00617200001_02101_00001_nrcb1_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrcb2/jw00617200001_02101_00001_nrcb2_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrcb3/jw00617200001_02101_00001_nrcb3_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrcb4/jw00617200001_02101_00001_nrcb4_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617200001_02101_00001_nrcblong/jw00617200001_02101_00001_nrcblong_rate.fits
#
# Checking jw00617200001_02101_00001_nrca1_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617200001_02101_00001_nrca1_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617200001_02101_00001_nrca2_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617200001_02101_00001_nrca2_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617200001_02101_00001_nrca3_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617200001_02101_00001_nrca3_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617200001_02101_00001_nrca4_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617200001_02101_00001_nrca4_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617200001_02101_00001_nrcalong_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617200001_02101_00001_nrcalong_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617200001_02101_00001_nrcb1_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617200001_02101_00001_nrcb1_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617200001_02101_00001_nrcb2_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617200001_02101_00001_nrcb2_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617200001_02101_00001_nrcb3_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617200001_02101_00001_nrcb3_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617200001_02101_00001_nrcb4_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617200001_02101_00001_nrcb4_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617200001_02101_00001_nrcblong_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617200001_02101_00001_nrcblong_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
#
#
# OBSERVATION: 201
#
# Total number of expected files: 10
# Expected detectors used: ['NRCA1', 'NRCA2', 'NRCA3', 'NRCA4', 'NRCALONG', 'NRCB1', 'NRCB2', 'NRCB3', 'NRCB4', 'NRCBLONG']
# Found uncal files:
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrca1/jw00617201001_02101_00001_nrca1_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrca2/jw00617201001_02101_00001_nrca2_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrca3/jw00617201001_02101_00001_nrca3_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrca4/jw00617201001_02101_00001_nrca4_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrcalong/jw00617201001_02101_00001_nrcalong_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrcb1/jw00617201001_02101_00001_nrcb1_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrcb2/jw00617201001_02101_00001_nrcb2_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrcb3/jw00617201001_02101_00001_nrcb3_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrcb4/jw00617201001_02101_00001_nrcb4_uncal.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrcblong/jw00617201001_02101_00001_nrcblong_uncal.fits
#
# Found rate files:
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrca1/jw00617201001_02101_00001_nrca1_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrca2/jw00617201001_02101_00001_nrca2_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrca3/jw00617201001_02101_00001_nrca3_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrca4/jw00617201001_02101_00001_nrca4_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrcalong/jw00617201001_02101_00001_nrcalong_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrcb1/jw00617201001_02101_00001_nrcb1_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrcb2/jw00617201001_02101_00001_nrcb2_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrcb3/jw00617201001_02101_00001_nrcb3_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrcb4/jw00617201001_02101_00001_nrcb4_rate.fits
# /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/JWST/jw00617201001_02101_00001_nrcblong/jw00617201001_02101_00001_nrcblong_rate.fits
#
# Checking jw00617201001_02101_00001_nrca1_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617201001_02101_00001_nrca1_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617201001_02101_00001_nrca2_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617201001_02101_00001_nrca2_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617201001_02101_00001_nrca3_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617201001_02101_00001_nrca3_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617201001_02101_00001_nrca4_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617201001_02101_00001_nrca4_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617201001_02101_00001_nrcalong_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617201001_02101_00001_nrcalong_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617201001_02101_00001_nrcb1_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617201001_02101_00001_nrcb1_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617201001_02101_00001_nrcb2_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617201001_02101_00001_nrcb2_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617201001_02101_00001_nrcb3_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617201001_02101_00001_nrcb3_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617201001_02101_00001_nrcb4_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617201001_02101_00001_nrcb4_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
#
#
# Checking jw00617201001_02101_00001_nrcblong_uncal.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
#
# Checking jw00617201001_02101_00001_nrcblong_rate.fits
# ----------------------------------------------------
# Requested readout pattern BRIGHT1 is valid. Using the nframe = 1 and nskip = 1
# No inconsistencies. File header info correct.
# WARNING: AstropyDeprecationWarning: /Volumes/LaCie/gseg_validation_tests/gseg3_july2020_RunForTheRecord/outputs/summary_table.txt already exists. Automatically overwriting ASCII files is deprecated. Use the argument 'overwrite=True' in the future. [astropy.io.ascii.ui]
